# %%
import pandas as pd
import nltk
from nltk.metrics import edit_distance
from nltk import word_tokenize, pos_tag
from nltk.tokenize import sent_tokenize


nltk.download('averaged_perceptron_tagger')

def calculate_accuracy(reference, hypothesis):
    
    intersection_size = len(reference.intersection(hypothesis))
    union_size = len(reference.union(hypothesis))
    
    
    accuracy = intersection_size / union_size if union_size != 0 else 0
    
    return accuracy

def identify_fillers(transcription):
    
    return set(["um", "uh"])  

def identify_repetitions(transcription):
    if not isinstance(transcription, str):
        return set()
    
    tokens = word_tokenize(transcription)
    return set([word.lower() for word in tokens if tokens.count(word) > 1])

def identify_proper_nouns(transcription):
    if not isinstance(transcription, str):
        return set()
    
    tokens = word_tokenize(transcription)
    tagged_tokens = pos_tag(tokens)
    return set([word.lower() for word, pos in tagged_tokens if pos == 'NNP'])

def evaluate_specific_elements(reference_transcription, automatic_transcription):
    if not isinstance(reference_transcription, str):
        reference_transcription = ''
    if not isinstance(automatic_transcription, str):
        automatic_transcription = ''

    reference_fillers = identify_fillers(reference_transcription)
    reference_repetitions = identify_repetitions(reference_transcription)
    reference_proper_nouns = identify_proper_nouns(reference_transcription)

    automatic_fillers = identify_fillers(automatic_transcription)
    automatic_repetitions = identify_repetitions(automatic_transcription)
    automatic_proper_nouns = identify_proper_nouns(automatic_transcription)

    filler_accuracy = calculate_accuracy(reference_fillers, automatic_fillers)
    repetition_accuracy = calculate_accuracy(reference_repetitions, automatic_repetitions)
    proper_nouns_accuracy = calculate_accuracy(reference_proper_nouns, automatic_proper_nouns)

    return filler_accuracy, repetition_accuracy, proper_nouns_accuracy


dataset = pd.read_csv('annotation_fake.csv')


for index, row in dataset.iterrows():
    Gold_transcription = row['gold standard transcription']
    automatic_transcription = row['Automatic Transcription']

    filler_accuracy, repetition_accuracy, proper_nouns_accuracy = evaluate_specific_elements(Gold_transcription, automatic_transcription)

    print(f"Example {index + 1}:")
    print(f"Gold Transcription: {Gold_transcription}")
    print(f"Automatic Transcription: {automatic_transcription}")
    print(f"Filler Words Accuracy: {filler_accuracy:.2%}")
    print(f"Repetition Accuracy: {repetition_accuracy:.2%}")
    print(f"Proper Nouns Accuracy: {proper_nouns_accuracy:.2%}")
    print("-" * 50)
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno 11001] getaddrinfo failed>
# Example 1:
# Gold Transcription: welcome
# Automatic Transcription: welcome
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 2:
# Gold Transcription: I went home
# Automatic Transcription: I went home
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 3:
# Gold Transcription:  That's my, That's my, That's my friend name
# Automatic Transcription: That's my, That's my friend name
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 75.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 4:
# Gold Transcription: I just got out of the home didn't did. Uh One day I was sad with Hab syndrome
# Automatic Transcription: I just got out of the home didn't did. Uh One day I was sad with hat syndrome
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 5:
# Gold Transcription: Okay
# Automatic Transcription: okay
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 6:
# Gold Transcription: thanks
# Automatic Transcription: thanks
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 7:
# Gold Transcription: Um, But maybe i'm not very happy
# Automatic Transcription: Um, But maybe i'm not very happy
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 100.00%
# --------------------------------------------------
# Example 8:
# Gold Transcription: its alright It's okay. You know.
# Automatic Transcription: its alright It's ok. You know.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 9:
# Gold Transcription: All right.
# Automatic Transcription: All right.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 10:
# Gold Transcription: I'm not doing no  you mean.
# Automatic Transcription: I'm not doing no  you mean.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 11:
# Gold Transcription: Okay.
# Automatic Transcription: right
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 12:
# Gold Transcription: Yeah, why not? Why not? I'll take. Why not? If I am
# Automatic Transcription: Yeah, why not?  I'll take. Why not? If I did
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 75.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 13:
# Gold Transcription: Obviously,
# Automatic Transcription: Obviously,
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 14:
# Gold Transcription: I believe
# Automatic Transcription:  believe
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 15:
# Gold Transcription: Awesome. Wow. That's some good. Got Marfac syndrome. Went to go see Metallical
# Automatic Transcription: Awesome. Wow. That's some moment. Got Marfacc syndrome. Went to go see Metallical
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 60.00%
# --------------------------------------------------
# Example 16:
# Gold Transcription: He got a car out of Garden.  Turned out it was because of the Martac. Yep
# Automatic Transcription: He got a car out of Garden.  Turned out it was because of the Mart. Yep
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 33.33%
# --------------------------------------------------
# Example 17:
# Gold Transcription: Yeah, well, you know what?
# Automatic Transcription: Yeah, well, you know what?
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 18:
# Gold Transcription:  I'm not ready to go there.
# Automatic Transcription:  not ready to go there.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 19:
# Gold Transcription: I would say  Shaner Pacelli.
# Automatic Transcription: I would say  Shane Pacelli.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 33.33%
# --------------------------------------------------
# Example 20:
# Gold Transcription: Oh. Yeah I was at--
# Automatic Transcription: Oh. Yeah I was at--
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 21:
# Gold Transcription: What? That's the one .
# Automatic Transcription: What? That's the one .
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 22:
# Gold Transcription:  Vincentx because I relocated over here, and I actually just went to Coumadingf just yesterday because.
# Automatic Transcription:  Vincentr because I relocated over here, and I actually just went to Coumadingf just yesterday because.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 33.33%
# --------------------------------------------------
# Example 23:
# Gold Transcription:  I moved here, so it's-- one minute. Hold on a second. Oh, car.
# Automatic Transcription:  I moved here, so it's-- one minute. Hold on a second. Oh, car.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 24:
# Gold Transcription: Not really.
# Automatic Transcription: Not really.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 25:
# Gold Transcription: No, I don't have none of that-- no. None of that crap.
# Automatic Transcription: No, I don't have none of that. None of that crap.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 26:
# Gold Transcription: Yeah. Oh, what was I-- oh. Oh. Wait a minute. Wait a minute. Hold on. Hold on a second.
# Automatic Transcription: Yeah. Oh, what was I-- oh. Oh.  minute. Wait a minute. Hold on. Hold on
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 71.43%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 27:
# Gold Transcription: I don't know. I don't know.
# Automatic Transcription: I don't know. I don't know.
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 28:
# Gold Transcription: Oh, yeah. Brinsterss, yeah. Yeah. Him, yeah, definitely.  few days after I got out of. Yeah.
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 29:
# Gold Transcription:  that's on my refrigerator. On my refrigerator, on the side. Happy to help
# Automatic Transcription:  that's on my refrigerator. On my refrigerator, on . Happy to help
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 100.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 30:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 31:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 32:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 33:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 34:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 35:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 36:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 37:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 38:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 39:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 40:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 41:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 42:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
# Example 43:
# Gold Transcription: nan
# Automatic Transcription: nan
# Filler Words Accuracy: 100.00%
# Repetition Accuracy: 0.00%
# Proper Nouns Accuracy: 0.00%
# --------------------------------------------------
